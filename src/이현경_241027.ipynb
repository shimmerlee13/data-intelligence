# %%
import pandas as pd
import os

# data 폴더 경로 설정
data_folder = "../data"

# 데이터 불러올 CSV 파일 이름 지정
csv_file = "1_한국환경공단_석면조사대상건축물현황(공공건축물)_20231019.csv"  # 불러올 파일명을 여기에 적어 주세요

# 전체 경로로 CSV 파일 읽기
file_path = os.path.join(data_folder, csv_file)
df = pd.read_csv(file_path)

# 데이터프레임 출력
print(df)
# Out:
#        석면건축물_일련번호                     도로명주소                 건축물명     건축물_동명  \
# 0               1  서울특별시 종로구 평창문화로 101(평창동)              평창동 차고지    평창동 차고지
# 1               2     서울특별시 종로구 동숭길 3 (동숭동)                예술가의집      예술가의집
# 2               3    서울특별시 종로구 창덕궁길 19(원서동)               현대문화센터     현대문화센터
# 3               4    서울특별시 종로구 청와대로 1 (세종로)               101경비단        신청사
# 4               5    서울특별시 종로구 숭인동길 63(숭인동)      종로소방서 숭인119안전센터  숭인119안전센터
# ...           ...                       ...                  ...        ...
# 33085       33086       강원도 양양군 강현면 물치천로 23               강현복지회관        NaN
# 33086       33087     강원도 양양군 양양읍 양양로 114 5               종합복지회관      일출웨딩홀
# 33087       33088       강원도 양양군 강현면 장산1길 42            강현하수종말처리장  강현하수종말처리장
# 33088       33089        강원도 양양군 양양읍 관아길 32               양양읍사무소         본관
# 33089       33090       강원도 양양군 서면 미천골길 120  국립자연휴양림관리소 미천골자연휴양림        NaN
#
# ...

# %%
# data 폴더에서 모든 CSV 파일을 불러와 딕셔너리 형태로 반환
csv_data = load_csv_files_from_data_folder()

# 특정 파일의 데이터에 접근 (예: "example.csv" 파일이 있는 경우)
df_example = csv_data.get("example.csv")
print(df_example.head())
